# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = 0)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = -1)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = 0.3)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = -1.037 + 0.17j)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = -0.624 + 0.435j)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = -0.8 + 0.2j)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = -0.835 - 0.2321j)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = 7)
c0Plane.show()
# Out:
# init fx

# %%
#C = 0
import cplane_np_hw as cp

c0Plane = cp.JuliaPlane(d = -2)
c0Plane.show()
# Out:
# init fx

# %%
c0Plane = cp.JuliaPlane(d = -7)
c0Plane.show()
# Out:
# init fx

# %%
c0Plane = cp.JuliaPlane(d = 2)
c0Plane.show()
# Out:
# init fx
