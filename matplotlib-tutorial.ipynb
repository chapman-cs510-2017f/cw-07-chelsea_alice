# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#SIMPLE PLOT
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c,s = np.cos(x), np.sin(x)


#-------------------------------------------------
plt.plot(x,c)
plt.plot(x,s)

plt.show()
#-------------------------------------------------

# %%
plt.figure(figsize=(8, 6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.plot(x, c, color="blue", linewidth=1.0, linestyle="-")
plt.plot(x, s, color="green", linewidth=1.0, linestyle="-")

plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))

plt.show()

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))

plt.show()

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))

plt.show()

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))

plt.show()

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

plt.xlim(x.min() * 1.1, X.max() * 1.1)
plt.ylim(c.min() * 1.1, C.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")



plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6f8bd9c115f3> in <module>()
#       9 plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])
#      10
# ---> 11 plt.xlim(x.min() * 1.1, X.max() * 1.1)
#      12 plt.ylim(c.min() * 1.1, C.max() * 1.1)
#      13
#
# NameError: name 'X' is not defined

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

plt.xlim(x.min() * 1.1, X.max() * 1.1)
plt.ylim(c.min() * 1.1, C.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

#axis  stuff
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))


plt.show()

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.ylim(c.min() * 1.1, c.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

#axis  stuff
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#leg
plt.legend(loc='upper left')
plt.show()
# Out:
# /ext/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.ylim(c.min() * 1.1, c.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

#axis  stuff
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#leg
plt.legend(loc='upper left')

#labelPoints

t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='red', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plt.show()
# Out:
# /ext/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.subplot(1, 1, 1)

plt.plot(x,c)
plt.plot(x,s)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.ylim(c.min() * 1.1, c.max() * 1.1)

plt.plot(x, c, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")

#axis  stuff
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#leg
plt.legend(loc='upper left')

#labelPoints

t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='red', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

#ticks
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65))
    
plt.show()
# Out:
# /ext/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)
t = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)
plt.clabel(t, inline=1, fontsize=10)

plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 10
x = np.linspace(-3, 3, 4 * n)
y = np.linspace(-3, 3, 3 * n)
X, Y = np.meshgrid(x, y)
plt.imshow(f(X, Y),  cmap = 'bone')

plt.colorbar(shrink = 0.9)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)
ax.set_zlim(-2, 2)
# Out:
# (-2, 2)

# %%
# Out:
# init fx
# [[-2.00000000-2.j         -2.00000000-1.995996j   -2.00000000-1.99199199j
#   ..., -2.00000000+1.99199199j -2.00000000+1.995996j   -2.00000000+2.j        ]
#  [-1.99599600-2.j         -1.99599600-1.995996j   -1.99599600-1.99199199j
#   ..., -1.99599600+1.99199199j -1.99599600+1.995996j   -1.99599600+2.j        ]
#  [-1.99199199-2.j         -1.99199199-1.995996j   -1.99199199-1.99199199j
#   ..., -1.99199199+1.99199199j -1.99199199+1.995996j   -1.99199199+2.j        ]
#  ...,
#  [ 1.99199199-2.j          1.99199199-1.995996j    1.99199199-1.99199199j
#   ...,  1.99199199+1.99199199j  1.99199199+1.995996j    1.99199199+2.j        ]
#  [ 1.99599600-2.j          1.99599600-1.995996j    1.99599600-1.99199199j
#   ...,  1.99599600+1.99199199j  1.99599600+1.995996j    1.99599600+2.j        ]
#  [ 2.00000000-2.j          2.00000000-1.995996j    2.00000000-1.99199199j
#   ...,  2.00000000+1.99199199j  2.00000000+1.995996j    2.00000000+2.j        ]]
# a.c
# (-2, 2, 1000, -2, 2, 1000)
# a.plane.shape
# (1000, 1000)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0658040e59ed> in <module>()
#       6 print("a.plane.shape")
#       7 print(a.plane.shape)
# ----> 8 a.show()
#
# ~/CS510/CW/cw-07-chelsea_alice/cplane_np_hw.py in show(self)
#      70 #         self.c = csv[1]
#      71     def show(self):
# ---> 72         #need x of  reals, y of complex, but now they're all reals...
#      73         plt.imshow(self.plane,  cmap = 'bone')
#      74
#
# NameError: name 'plt' is not defined
