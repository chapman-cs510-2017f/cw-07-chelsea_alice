# %%
import cplane_np_hw as cp
import numpy as np
import matplotlib.pyplot as plt
a = cp.JuliaPlane()
print("a.c")
print(a.c)
print("a.plane.shape")
print(a.plane.shape)
a.show()
# Out:
# init fx
# [[-2.00000000-2.j         -2.00000000-1.95959596j -2.00000000-1.91919192j
#   ..., -2.00000000+1.91919192j -2.00000000+1.95959596j -2.00000000+2.j        ]
#  [-1.95959596-2.j         -1.95959596-1.95959596j -1.95959596-1.91919192j
#   ..., -1.95959596+1.91919192j -1.95959596+1.95959596j -1.95959596+2.j        ]
#  [-1.91919192-2.j         -1.91919192-1.95959596j -1.91919192-1.91919192j
#   ..., -1.91919192+1.91919192j -1.91919192+1.95959596j -1.91919192+2.j        ]
#  ...,
#  [ 1.91919192-2.j          1.91919192-1.95959596j  1.91919192-1.91919192j
#   ...,  1.91919192+1.91919192j  1.91919192+1.95959596j  1.91919192+2.j        ]
#  [ 1.95959596-2.j          1.95959596-1.95959596j  1.95959596-1.91919192j
#   ...,  1.95959596+1.91919192j  1.95959596+1.95959596j  1.95959596+2.j        ]
#  [ 2.00000000-2.j          2.00000000-1.95959596j  2.00000000-1.91919192j
#   ...,  2.00000000+1.91919192j  2.00000000+1.95959596j  2.00000000+2.j        ]]
# ------------------------------
# ...
